# %%
# !git clone https://github.com/vleonel-junior/Sparse-FT_Transformer-Plus.git

# %%
import sys
sys.path.append('/kaggle/working/Sparse-FT_Transformer-Plus')

# %%
# Le bon chemin est directement :
import os
os.chdir('/kaggle/working/Sparse-FT_Transformer-Plus')

# Vérifier que vous êtes au bon endroit
# !pwd
# !ls -la

# %%
# Installer les dépendances
# !pip install "scikit-learn>=1.0,<2" -qqq > /dev/null 2>&1 && echo 'Installation de scikit-learn réussie'
# !pip install libzero==0.0.4 -qqq > /dev/null 2>&1 && echo 'Installation de libzero réussie'
# !pip install optuna -qqq > /dev/null 2>&1 && echo 'Installation de optuna réussie'
# !pip install sparsemax -qqq > /dev/null 2>&1 && echo 'Installation de sparsemax réussie'
# !pip install icecream -qqq > /dev/null 2>&1 && echo 'Installation de icecream réussie'
# !pip install pytomlpp -qqq > /dev/null 2>&1 && echo 'Installation de pytomlpp réussie'

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch
print("CUDA disponible :", torch.cuda.is_available())
print("Indice du GPU :", torch.cuda.current_device())
print("Nom du GPU :", torch.cuda.get_device_name(torch.cuda.current_device()))

# %% [markdown]
# # Publics Datasets

# %% [markdown]
# <center><h2  style="color:white; background-color:#808b96; border-radius: 10px; padding:15px;"> Helena </h2></center>
#     Task type : Multiclass

# %% [markdown]
# ### *Catboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/helena/catboost/tuning/0.toml

# %% [markdown]
# ### *ft-transformer*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/helena/ft_transformer/tuning/0.toml

# %% [markdown]
# ### *sparse ft-transformer +*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/helena/sparse_ftt_plus/tuning/0.toml

# %% [markdown]
# ### *mlp*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/helena/mlp/tuning/0.toml

# %% [markdown]
# ### *xgboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/helena/xgboost/tuning/0.toml

# %% [markdown]
# <center><h2  style="color:white; background-color:#808b96; border-radius: 10px; padding:15px;"> Jannis </h2></center>
#     Task type : Multiclass

# %% [markdown]
# ### *Catboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/jannis/catboost/tuning/0.toml

# %% [markdown]
# ### *ft-transformer*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/jannis/ft_transformer/tuning/0.toml

# %% [markdown]
# ### **sparse ft-transformer +**

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/jannis/sparse_ftt_plus/tuning/0.toml

# %% [markdown]
# ### *mlp*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/jannis/mlp/tuning/0.toml

# %% [markdown]
# ### *xgboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/jannis/xgboost/tuning/0.toml

# %% [markdown]
# <center><h2  style="color:white; background-color:#808b96; border-radius: 10px; padding:15px;"> Higgs Small </h2></center>
#     Task type : Binclass

# %% [markdown]
# ### *Catboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/higgs_small/catboost/tuning/0.toml

# %% [markdown]
# ### *ft-transformer*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/higgs_small/ft_transformer/tuning/0.toml

# %% [markdown]
# ### *sparse ft-transformer +*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/higgs_small/sparse_ftt_plus/tuning/0.toml

# %% [markdown]
# ### *mlp*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/higgs_small/mlp/tuning/0.toml

# %% [markdown]
# ### *xgboost*

# %%
# !PYTHONPATH=/kaggle/working/Sparse-FT_Transformer-Plus python /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/bin/tune.py -f /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output/higgs_small/xgboost/tuning/0.toml

# %% [markdown]
# ### *Download output*

# %%
# !zip -r output.zip /kaggle/working/Sparse-FT_Transformer-Plus/rtdl_revisiting_models/output
